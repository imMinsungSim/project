# %%
import re
import pandas as pd
from pathlib import Path
from openpyxl import load_workbook

# %%
input_path = Path.home() / "Desktop" / "Data_A1.xlsx"
SHEET_NAME = "Sheet1"
COL_MAIN = "예약번호"
COL_DETAIL = "상담내용"
COL_TEST = "예약번호_test"

# %%
pattern_A = re.compile(r"(?i)\b[A-Z]\d{7}\b")
pattern_B = re.compile(r"(?i)\b(?=[A-Z0-9]{6}\b)(?=.*[A-Z])(?=.*\d)[A-Z0-9]{6}\b")
pattern_C = re.compile(r"(?i)\b[A-Z]{6}\b")
pattern_D = re.compile(r"\b\d{7}\b")
pattern_E = re.compile(r"\b\d{8}\b")
